# %%
library("data.table")

# %%
df <- fread("/mnt/project/Bulk/Genotype Results/Genotype calls/ukb_rel.dat")

# %%
get_id_to_drop <- function(tmp){
    tmp[
        , .(ID = c(ID1, ID2))
    ][
        , .(n = .N), by = ID
    ][
        order(-n)[1], ID
    ]
}

# %%
# list of all IDs, to mark which ones to drop
ID_list <- df[, .(ID = unique(c(ID1, ID2)))]

# %%
# set indicator variable to mark pairs still present
# using the current ID drop set
df[, mask := TRUE]

# initially set all IDs as retained
ID_list[, drop := FALSE]

# iterate IDs from the one with most relatives,
# stop when no pairs remain
while (df[mask == TRUE, .N] > 0) {
    # mask pairs removed by dropping the ID with most relatives
    the_id <- get_id_to_drop(df[mask == TRUE])
    df[ID1 == the_id | ID2 == the_id, mask := FALSE]
    ID_list[ID == the_id, drop := TRUE]
    if ((ID_list[, sum(drop)] %% 1000) == 0) message(
        sprintf(
            "Dropped %s IDs of %s, %s ID pairs remaining",
            ID_list[, sum(drop)],
            nrow(ID_list),
            df[mask == TRUE, .N]
        )
    )
    
    if (df[mask == TRUE, .N] == 0) {
        break
    }
}
# Out:
# Dropped 1000 IDs of 147518, 97322 ID pairs remaining
#
# Dropped 2000 IDs of 147518, 93768 ID pairs remaining
#
# Dropped 3000 IDs of 147518, 90768 ID pairs remaining
#
# Dropped 4000 IDs of 147518, 87768 ID pairs remaining
#
# Dropped 5000 IDs of 147518, 84768 ID pairs remaining
#
# Dropped 6000 IDs of 147518, 82359 ID pairs remaining
#
# Dropped 7000 IDs of 147518, 80359 ID pairs remaining
#
# Dropped 8000 IDs of 147518, 78359 ID pairs remaining
#
# Dropped 9000 IDs of 147518, 76359 ID pairs remaining
#
# Dropped 10000 IDs of 147518, 74359 ID pairs remaining
#
# Dropped 11000 IDs of 147518, 72359 ID pairs remaining
#
# Dropped 12000 IDs of 147518, 70359 ID pairs remaining
#
# Dropped 13000 IDs of 147518, 68359 ID pairs remaining
#
# Dropped 14000 IDs of 147518, 66359 ID pairs remaining
#
# Dropped 15000 IDs of 147518, 64359 ID pairs remaining
#
# Dropped 16000 IDs of 147518, 62359 ID pairs remaining
#
# Dropped 17000 IDs of 147518, 60359 ID pairs remaining
#
# Dropped 18000 IDs of 147518, 58359 ID pairs remaining
#
# Dropped 19000 IDs of 147518, 56359 ID pairs remaining
#
# Dropped 20000 IDs of 147518, 54570 ID pairs remaining
#
# Dropped 21000 IDs of 147518, 53570 ID pairs remaining
#
# Dropped 22000 IDs of 147518, 52570 ID pairs remaining
#
# Dropped 23000 IDs of 147518, 51570 ID pairs remaining
#
# Dropped 24000 IDs of 147518, 50570 ID pairs remaining
#
# Dropped 25000 IDs of 147518, 49570 ID pairs remaining
#
# Dropped 26000 IDs of 147518, 48570 ID pairs remaining
#
# Dropped 27000 IDs of 147518, 47570 ID pairs remaining
#
# Dropped 28000 IDs of 147518, 46570 ID pairs remaining
#
# Dropped 29000 IDs of 147518, 45570 ID pairs remaining
#
# Dropped 30000 IDs of 147518, 44570 ID pairs remaining
#
# Dropped 31000 IDs of 147518, 43570 ID pairs remaining
#
# Dropped 32000 IDs of 147518, 42570 ID pairs remaining
#
# Dropped 33000 IDs of 147518, 41570 ID pairs remaining
#
# Dropped 34000 IDs of 147518, 40570 ID pairs remaining
#
# Dropped 35000 IDs of 147518, 39570 ID pairs remaining
#
# Dropped 36000 IDs of 147518, 38570 ID pairs remaining
#
# Dropped 37000 IDs of 147518, 37570 ID pairs remaining
#
# Dropped 38000 IDs of 147518, 36570 ID pairs remaining
#
# Dropped 39000 IDs of 147518, 35570 ID pairs remaining
#
# Dropped 40000 IDs of 147518, 34570 ID pairs remaining
#
# Dropped 41000 IDs of 147518, 33570 ID pairs remaining
#
# Dropped 42000 IDs of 147518, 32570 ID pairs remaining
#
# Dropped 43000 IDs of 147518, 31570 ID pairs remaining
#
# Dropped 44000 IDs of 147518, 30570 ID pairs remaining
#
# Dropped 45000 IDs of 147518, 29570 ID pairs remaining
#
# Dropped 46000 IDs of 147518, 28570 ID pairs remaining
#
# Dropped 47000 IDs of 147518, 27570 ID pairs remaining
#
# Dropped 48000 IDs of 147518, 26570 ID pairs remaining
#
# Dropped 49000 IDs of 147518, 25570 ID pairs remaining
#
# Dropped 50000 IDs of 147518, 24570 ID pairs remaining
#
# Dropped 51000 IDs of 147518, 23570 ID pairs remaining
#
# Dropped 52000 IDs of 147518, 22570 ID pairs remaining
#
# Dropped 53000 IDs of 147518, 21570 ID pairs remaining
#
# Dropped 54000 IDs of 147518, 20570 ID pairs remaining
#
# Dropped 55000 IDs of 147518, 19570 ID pairs remaining
#
# Dropped 56000 IDs of 147518, 18570 ID pairs remaining
#
# Dropped 57000 IDs of 147518, 17570 ID pairs remaining
#
# Dropped 58000 IDs of 147518, 16570 ID pairs remaining
#
# Dropped 59000 IDs of 147518, 15570 ID pairs remaining
#
# Dropped 60000 IDs of 147518, 14570 ID pairs remaining
#
# Dropped 61000 IDs of 147518, 13570 ID pairs remaining
#
# Dropped 62000 IDs of 147518, 12570 ID pairs remaining
#
# Dropped 63000 IDs of 147518, 11570 ID pairs remaining
#
# Dropped 64000 IDs of 147518, 10570 ID pairs remaining
#
# Dropped 65000 IDs of 147518, 9570 ID pairs remaining
#
# Dropped 66000 IDs of 147518, 8570 ID pairs remaining
#
# Dropped 67000 IDs of 147518, 7570 ID pairs remaining
#
# Dropped 68000 IDs of 147518, 6570 ID pairs remaining
#
# Dropped 69000 IDs of 147518, 5570 ID pairs remaining
#
# Dropped 70000 IDs of 147518, 4570 ID pairs remaining
#
# Dropped 71000 IDs of 147518, 3570 ID pairs remaining
#
# Dropped 72000 IDs of 147518, 2570 ID pairs remaining
#
# Dropped 73000 IDs of 147518, 1570 ID pairs remaining
#
# Dropped 74000 IDs of 147518, 570 ID pairs remaining

# %%
# check if I can include the ID and still have no close relative pairs
# since I drop from the most connected IDs I am not guaranteed that there will not
# be some redundant drops were all the connection of 1 ID have also been dropped
dropped_ids <- ID_list[drop == TRUE, ID]
n_recovered <- 0
n_checked <- 0
n_dropped <- ID_list[, sum(drop)]
for (id in dropped_ids){
    recoverable <- df[
        (
            ((ID1 == id) & !(ID2 %in% dropped_ids)) |
            ((ID2 == id) & !(ID1 %in% dropped_ids))
        ),
        .N == 0
    ]
    if (recoverable) {
        n_recovered <- n_recovered + 1
        ID_list[ID == id, drop := FALSE]
        dropped_ids <- ID_list[drop == TRUE, ID]
    }
    n_checked <- n_checked + 1
    if ((n_checked %% 1000) == 0){
        message(
            sprintf(
                "Recovered %s IDs of %s, %s IDs remaining to check",
                n_recovered,
                n_dropped,
                n_dropped - n_checked
            )
        )
    }
}
# Out:
# Recovered 0 IDs of 74569, 73569 IDs remaining to check
#
# Recovered 0 IDs of 74569, 72569 IDs remaining to check
#
# Recovered 0 IDs of 74569, 71569 IDs remaining to check
#
# Recovered 0 IDs of 74569, 70569 IDs remaining to check
#
# Recovered 0 IDs of 74569, 69569 IDs remaining to check
#
# Recovered 0 IDs of 74569, 68569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 67569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 66569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 65569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 64569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 63569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 62569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 61569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 60569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 59569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 58569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 57569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 56569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 55569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 54569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 53569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 52569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 51569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 50569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 49569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 48569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 47569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 46569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 45569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 44569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 43569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 42569 IDs remaining to check
#
# Recovered 1 IDs of 74569, 41569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 40569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 39569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 38569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 37569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 36569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 35569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 34569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 33569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 32569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 31569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 30569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 29569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 28569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 27569 IDs remaining to check
#
# Recovered 2 IDs of 74569, 26569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 25569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 24569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 23569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 22569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 21569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 20569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 19569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 18569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 17569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 16569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 15569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 14569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 13569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 12569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 11569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 10569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 9569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 8569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 7569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 6569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 5569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 4569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 3569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 2569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 1569 IDs remaining to check
#
# Recovered 3 IDs of 74569, 569 IDs remaining to check

# %%
ids_to_drop <- ID_list[drop == TRUE, .(ID)]

# %%
# no pair remains when I remove pairs containing IDs in ids_to_drop
stopifnot(df[!(ID1 %in% ids_to_drop[["ID"]] | ID2 %in% ids_to_drop[["ID"]]), .N] == 0)

# %%
# no ID should be recoverable anymore
dropped_ids <- ID_list[drop == TRUE, ID]
n_checked <- 0
n_dropped <- ID_list[, sum(drop)]
for (id in dropped_ids){
    recoverable <- df[
        (
            ((ID1 == id) & !(ID2 %in% dropped_ids)) |
            ((ID2 == id) & !(ID1 %in% dropped_ids))
        ),
        .N == 0
    ]
    stopifnot(!recoverable)
    n_checked <- n_checked + 1
    if ((n_checked %% 1000) == 0){
        message(
            sprintf(
                "Checked %s IDs of %s",
                n_checked,
                n_dropped
            )
        )
    }
}
# Out:
# Checked 1000 IDs of 74566
#
# Checked 2000 IDs of 74566
#
# Checked 3000 IDs of 74566
#
# Checked 4000 IDs of 74566
#
# Checked 5000 IDs of 74566
#
# Checked 6000 IDs of 74566
#
# Checked 7000 IDs of 74566
#
# Checked 8000 IDs of 74566
#
# Checked 9000 IDs of 74566
#
# Checked 10000 IDs of 74566
#
# Checked 11000 IDs of 74566
#
# Checked 12000 IDs of 74566
#
# Checked 13000 IDs of 74566
#
# Checked 14000 IDs of 74566
#
# Checked 15000 IDs of 74566
#
# Checked 16000 IDs of 74566
#
# Checked 17000 IDs of 74566
#
# Checked 18000 IDs of 74566
#
# Checked 19000 IDs of 74566
#
# Checked 20000 IDs of 74566
#
# Checked 21000 IDs of 74566
#
# Checked 22000 IDs of 74566
#
# Checked 23000 IDs of 74566
#
# Checked 24000 IDs of 74566
#
# Checked 25000 IDs of 74566
#
# Checked 26000 IDs of 74566
#
# Checked 27000 IDs of 74566
#
# Checked 28000 IDs of 74566
#
# Checked 29000 IDs of 74566
#
# Checked 30000 IDs of 74566
#
# Checked 31000 IDs of 74566
#
# Checked 32000 IDs of 74566
#
# Checked 33000 IDs of 74566
#
# Checked 34000 IDs of 74566
#
# Checked 35000 IDs of 74566
#
# Checked 36000 IDs of 74566
#
# Checked 37000 IDs of 74566
#
# Checked 38000 IDs of 74566
#
# Checked 39000 IDs of 74566
#
# Checked 40000 IDs of 74566
#
# Checked 41000 IDs of 74566
#
# Checked 42000 IDs of 74566
#
# Checked 43000 IDs of 74566
#
# Checked 44000 IDs of 74566
#
# Checked 45000 IDs of 74566
#
# Checked 46000 IDs of 74566
#
# Checked 47000 IDs of 74566
#
# Checked 48000 IDs of 74566
#
# Checked 49000 IDs of 74566
#
# Checked 50000 IDs of 74566
#
# Checked 51000 IDs of 74566
#
# Checked 52000 IDs of 74566
#
# Checked 53000 IDs of 74566
#
# Checked 54000 IDs of 74566
#
# Checked 55000 IDs of 74566
#
# Checked 56000 IDs of 74566
#
# Checked 57000 IDs of 74566
#
# Checked 58000 IDs of 74566
#
# Checked 59000 IDs of 74566
#
# Checked 60000 IDs of 74566
#
# Checked 61000 IDs of 74566
#
# Checked 62000 IDs of 74566
#
# Checked 63000 IDs of 74566
#
# Checked 64000 IDs of 74566
#
# Checked 65000 IDs of 74566
#
# Checked 66000 IDs of 74566
#
# Checked 67000 IDs of 74566
#
# Checked 68000 IDs of 74566
#
# Checked 69000 IDs of 74566
#
# Checked 70000 IDs of 74566
#
# Checked 71000 IDs of 74566
#
# Checked 72000 IDs of 74566
#
# Checked 73000 IDs of 74566
#
# Checked 74000 IDs of 74566

# %%
ids_to_drop[, .N]
# Out:
# [1] 74566

# %%
fwrite(ids_to_drop, "ids_to_drop_close_relatives.txt")

# %%
system("dx upload ids_to_drop_close_relatives.txt --path genotypes/")
